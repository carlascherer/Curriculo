# %% [markdown]
# # CV Carla Trindade Scherer

# %%
##########   CV CARLA TRINDADE SCHERER   ##########

### TEXTS DEFINITION
Nota = '>>>This CV was made using Python/Jupyter Notebook (follow the QR code).<<<'
Nome = 'CARLA SCHERER'
Titulo = 'Data Analytics, Data Science & AI'
Contato = 'São Paulo, BR\n+55 51 993267470\ncarlatscherer@gmail.com\nLinked-In: carla-scherer-a4793b93/\nGitHub: carlascherer'

TituloQuemSouEu = 'WHO AM I'
linha1 = 'I have experience working with agile teams on Data'
linha2 = 'Science & AI projects, developing and maintaining '
linha3 = 'solutions for financial services to automate and scale'
linha4 = 'business flows using Artificial Intelligence in the'
linha5 = 'Cloud. I bring strong mathematical, analytical and'
linha6 = 'programming skills, combined with curiosity, the ability'
linha7 = 'to self-input, learn fast and adapt, which allows me'
linha8 = 'to excel in different tasks and environments. I hold '
linha9 = 'a Master’s degree in Civil Engineering with a focus on '
linha10 = 'mathematical modelling of structures (2016-2018). I am '
linha11 = 'Google Cloud (2021) and Azure (2020) certified and I '
linha12 = 'have been specializing in Data Science (2021-now) and '
linha13 = 'ML Engineering (2022-now) fields. I am motivated by '
linha14 = 'solving problems using logic and exact sciences and by '
linha15 = 'understanding how things work and why they are as they '
linha16 = 'are. I always try to push myself out of my comfort zone.'


conteudo_linhas = [linha1, linha2, linha3, linha4, linha5, 
                   linha6, linha7, linha8, linha9, linha10, 
                   linha11, linha12, linha13, linha14, linha15,
                   linha16]


TrabalhoTitulo = 'PROFESSIONAL EXPERIENCE'
TrabalhoZeroTitulo = 'Accenture / AI Engineering Senior Analyst'
TrabalhoZeroPeriodo = '10/2020-Now'
TrabalhoZeroDescr = '- Project 1: development of NLP model to extract information\n  from non-structured documents (text documents); model\n  improvement based on tracking of metrics.\n- Project 2: development of virtual assistants for collection\n  campaigns; design and implementation of the conversation flows,\n  NLP intents and entities; development of python code to manipu-\n  late data and integrate the bot application with external API.\n- Project 3: global data lake migration and modernization from\n  on-prem to GCP architecture for leading company in retail\n  industry; building of data pipelines, execution and trouble-\n  shooting of DAGs using airflow'
TrabalhoUmTitulo = 'RS Highways Company / CORSAN / Civil Engineer'
TrabalhoUmPeriodo = '07/2018-09/2020 - 02/2015-02/2016'
TrabalhoUmDescr = '- Coordination of engineering services\n- Elaboration of analysis reports and budgets using VBA\n- Automation of day-to-day engineering tasks'

EduTitulo = 'EDUCATION'
EduUmTitulo = 'UFRGS, MSc. Civil Eng. - Structures'
EduUmSubject = 'Research area: Wind Engineering/Wind Energy'
EduUmPeriodo = '2016-2018'
EduDoisTitulo = 'UFRGS, Civil Eng. | Electrical Eng. (Incomp.)'
EduDoisPeriodo = '2009-2013 | 2007-2009'
EduTresTitulo = 'DIGITAL HOUSE, Data Science'
EduTresPeriodo = 'mar-2020 - sep-2021'


#Programming languages description
titulo_linguagens = 'Progr. Lang./Libraries'
ling1 = '- Python' #.8
ling2 = '- Pandas/Numpy' #.7
ling3 = '- Scikit-learn' #.7
ling4 = '- SQL' #.4
ling5 = '- JavaScript' #.6
ling6 = '- Flask' #.4
ling7 = '- MatplotLib' #.5
ling_conteudo_linhas = [ling1, ling2, ling3, ling4, ling5, ling6, ling7]
ling_percentuais = [.8, .7, .7, .4, .6, .4, .5]

#Tools description
titulo_ferramentas = 'Tools'
ferr1 = '- GCP/Azure' #.7
ferr2 = '- DialogFlow' #.8
ferr3 = '- Watson KS' #.9
ferr4 = '- GCP AutoML' #.5
ferr5 = '- Power BI' #.4
ferr6 = '- Git/GitHub' #.5
ferr7 = '- Kubernetes' #.4
ferr8 = '- Excel' #.9
ferr_conteudo_linhas = [ferr1, ferr2, ferr3, ferr4, ferr5, ferr6, ferr7, ferr8]
ferr_percentuais = [.7, .8, .9, .5, .4, .5, .4, .9]

#Hard skills/knowledge description
titulo_habilidades = 'Knowledge'
hab1 = '- Math./Stats.' #.6
hab2 = '- NLP/NLU' #.8
hab3 = '- Cloud' #.6
hab4 = '- OCR/AI' #.7
hab5 = '- DevOps, CI/CD' #.4
hab_conteudo_linhas = [hab1, hab2, hab3, hab4, hab5]
hab_percentuais = [.6, .8, .7, .7, .5]

#Soft Skills description
titulo_soft = 'Soft Skills'
soft1 = '- Communication' #.5
soft2 = '- Colaboration' #.8
soft3 = '- Resilience' #.9
soft4 = '- Flexibility' #.6
soft5 = '- Creativity' #.5
soft_conteudo_linhas = [soft1, soft2, soft3, soft4, soft5]
soft_percentuais = [.5, .8, .9, .6, .5]

#Languages description
titulo_linguas = 'Languages'
linguas1 = '- English'
linguas2 = '- Spanish'
linguas_conteudo_linhas = [linguas1, linguas2]
linguas_percentuais = [0.7, 0.3]


# Setting style for bar graphs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Setting font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Setting colors
cinza = '#808080'
azul = '#2e2eb8'
branco = '#ffffff'

# Setting decorative lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color=cinza, alpha=0.4, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=1, xmin=0, xmax=1, color=azul, linewidth=141, alpha=0.5)

# Setting image background color
ax.set_facecolor('white')

# Removing axis
plt.axis('off')


### TEXT ANNOTATION

## Titles
plt.annotate(Nota, (.02,.99), weight='regular', fontsize=6.5, alpha=.75)
plt.annotate(Nome, (.02,.943), weight='bold', fontsize=20)
plt.annotate(Titulo, (.02,.91), weight='regular', fontsize=13)
plt.annotate(Contato, (.7,.906), weight='regular', fontsize=8, color='#ffffff')

## Who am I text

#Creating location vector
num_linhas = len(conteudo_linhas) + 1
loc_linha_inicial = .83
passo = -.014
loc_linha_final = loc_linha_inicial + passo * (num_linhas-1)
loc_linhas = pd.Series(  np.arange(loc_linha_inicial,loc_linha_final,passo)  , index=range(0,num_linhas-1))

#Text annotation
plt.annotate(TituloQuemSouEu, (.02,.85), weight='bold', fontsize=10, color=azul)
for i in loc_linhas.index:
    plt.annotate(conteudo_linhas[i], (.02,loc_linhas[i]), weight='regular', fontsize=7.8)

## Professional Experience text
plt.annotate(TrabalhoTitulo, (.02,.58), weight='bold', fontsize=10, color=azul)
plt.annotate(TrabalhoZeroTitulo, (.02,.555), weight='bold', fontsize=10)
plt.annotate(TrabalhoZeroPeriodo, (.02,.535), weight='regular', fontsize=9, alpha=.6)
plt.annotate(TrabalhoZeroDescr, (.04,.362), weight='regular', fontsize=8.7)
plt.annotate(TrabalhoUmTitulo, (.02,.332), weight='bold', fontsize=10)
plt.annotate(TrabalhoUmPeriodo, (.02,.31), weight='regular', fontsize=9, alpha=.6)
plt.annotate(TrabalhoUmDescr, (.04,.258), weight='regular', fontsize=9)


#Education text
plt.annotate(EduTitulo, (.02,.211), weight='bold', fontsize=10, color=azul)
plt.annotate(EduUmTitulo, (.02,.188), weight='bold', fontsize=10)
plt.annotate(EduUmSubject, (.02,.173), weight='regular', style='italic', fontsize=8)
plt.annotate(EduUmPeriodo, (.02,.153), weight='regular', fontsize=9, alpha=.6) #+15
plt.annotate(EduDoisTitulo, (.02,.113), weight='bold', fontsize=10) #+45
plt.annotate(EduDoisPeriodo, (.02,.093), weight='regular', fontsize=9, alpha=.6) #+15
plt.annotate(EduTresTitulo, (.02,.045), weight='bold', fontsize=10) #+45
plt.annotate(EduTresPeriodo, (.02,.025), weight='regular', fontsize=9, alpha=.6) #+15


################      FUNCTIONS TO CREATE BARS FOR PERFORMANCE EVALUATION

def locate_vector(titulo, quantidade, loc_linha_inicial, passo):
    loc_linha_final = round(loc_linha_inicial + passo * quantidade,2)
    print('Location of last line: ' + titulo + ' ' + str(loc_linha_final))
    vector = np.arange(loc_linha_inicial,loc_linha_final,passo)
    locate_vector = pd.Series(vector, index=range(0,len(vector)))
    return locate_vector
    
def lines(locate_vector, tamanho, percentuais, cor):
    for i in locate_vector.index:
        plt.axhline(y=locate_vector[i]+.0035, xmin=(1-tamanho*percentuais[i]), xmax=1, color=cor, linewidth=7, alpha=0.7)
        
def white_lines(locate_vector, tamanho, cor):
    for i in locate_vector.index:
        plt.axhline(y=locate_vector[i]+.0035, xmin=(1-tamanho), xmax=1, color=cor, linewidth=7, alpha=0.4)
        
def annotate(titulo, loc_titulo, conteudo, locate_vector):
    plt.annotate(titulo, (.7,loc_titulo), weight='bold', fontsize=10, color=azul)
    for i in locate_vector.index:
        plt.annotate(conteudo[i], (.7,locate_vector[i]), weight='regular', fontsize=9, color=branco)

#####     PROGRAMMING LANGUAGES/LIBRARIES     #####

ling_vector = locate_vector('Languages/Libraries', len(ling_conteudo_linhas), .82, -.02)
white_lines(ling_vector, .11, '#ffffff')
lines(ling_vector, .11, ling_percentuais, azul)
annotate(titulo_linguagens, .85, ling_conteudo_linhas, ling_vector)


#####     TOOLS     #####    

ferr_vector = locate_vector('Tools', len(ferr_conteudo_linhas), .62, -.02)
white_lines(ferr_vector, .11, '#ffffff')
lines(ferr_vector, .11, ferr_percentuais, azul)
annotate(titulo_ferramentas, .65, ferr_conteudo_linhas, ferr_vector)
    
#####     HARD SKILLS/KNOWLEDGE     #####

hab_vector = locate_vector('Skills/Knowledge', len(hab_conteudo_linhas), .38, -.02) #.38
white_lines(hab_vector, .11, '#ffffff')
lines(hab_vector, .11, hab_percentuais, azul)
annotate(titulo_habilidades, .41, hab_conteudo_linhas, hab_vector) #.41
    
#####     SOFT SKILLS     #####

soft_vector = locate_vector('Soft Skills', len(soft_conteudo_linhas), .22, -.02)
white_lines(soft_vector, .11, '#ffffff')
lines(soft_vector, .11, soft_percentuais, azul)
annotate(titulo_soft, .25, soft_conteudo_linhas, soft_vector)

#####     LANGUAGES     #####

# Drawing language circles
ax1 = fig.add_axes([0.47,0.58,0.2,0.2])
ax1.set_autoscale_on(True)
localizacao_ingles = (0.5,0.75)
localizacao_espanhol = (0.5,0.25)
raio = 0.18
circulo_background_ingles = plt.Circle(localizacao_ingles, raio, color=cinza, alpha=0.4)
circulo_background_espanhol = plt.Circle(localizacao_espanhol, raio, color=cinza, alpha=0.4)
circulo_ingles = plt.Circle(localizacao_ingles, raio*0.9, color=azul, alpha=0.7)
circulo_espanhol = plt.Circle(localizacao_espanhol, raio*0.25, color=azul, alpha=0.7)
ax1.set_aspect(1)
ax1.add_artist(circulo_background_ingles)
ax1.add_artist(circulo_background_espanhol)
ax1.add_artist(circulo_ingles)
ax1.add_artist(circulo_espanhol)

titulo_ingles = 'English'
plt.annotate(titulo_ingles, (.32,0.98), weight='bold', fontsize=10, color=azul)
titulo_espanhol = 'Spanish'
plt.annotate(titulo_espanhol, (.31,0.49), weight='bold', fontsize=10, color=azul)

plt.axis('off')

# Plotting QR code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('QR-Code.png')
imagebox = OffsetImage(arr_code, zoom=0.03)
ab = AnnotationBbox(imagebox, (0.835, 0.07))
ax.add_artist(ab)

# Saving png image
plt.savefig('CV-Carla-EN.png', dpi=300, bbox_inches='tight')

# # Saving pdf document
from PIL import Image
png = Image.open('CV-Carla-EN.png')
png.load() # required for png.split()
background = Image.new("RGB", png.size, (255, 255, 255))
background.paste(png, mask=png.split()[3]) # 3 is the alpha channel
background.save('CV-Carla-EN.pdf')
# Out:
# Location of last line: Languages/Libraries 0.68
# Location of last line: Tools 0.46
# Location of last line: Skills/Knowledge 0.28
# Location of last line: Soft Skills 0.12
