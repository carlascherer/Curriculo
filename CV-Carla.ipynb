# %% [markdown]
# # CV Carla Trindade Scherer

# %%
##########   CV CARLA TRINDADE SCHERER   ##########

### DEFINIÇÃO DE TEXTOS
Nota = '>>>Este CV foi feito utilizando Python/Jupyter Notebook (siga o QR Code).<<<'
Nome = 'CARLA SCHERER'
Titulo = 'Data Science & AI | Data Engineering'
Contato = 'São Paulo, SP\n+55 51 993267470\ncarlatscherer@gmail.com\nLinked-In: carla-scherer-a4793b93/\nGitHub: carlascherer'

TituloQuemSouEu = 'QUEM SOU EU'
linha1 = 'Sou mestre em engenharia e recentemente migrei'
linha2 = 'de carreira para a tecnologia, o que se '
linha3 = 'consolidou há quase um ano. Atualmente, trabalho'
linha4 = 'com OCR/IA utilizando Watson/IBM, entre outras'
linha5 = 'tecnologias. Estou na metade de um curso de Data'
linha6 = 'Science na Digital House e também estou tirando'
linha7 = 'algumas certificações de Cloud (Google, Azure).'
linha8 = 'Gosto muito de trabalhar com tecnologia pois'
linha9 = 'posso estar sempre estudando e aprendendo algo'
linha10 = 'novo e através dela tenho a oportunidade de ajudar'
linha11 = 'a resolver problemas utilizando ciências exatas,'
linha12 = 'que é algo que me motiva. Sou curiosa, gosto de'
linha13 = 'entender como as coisas funcionam e o porquê delas.'
linha14 = 'Aprendo muito rápido pois sou esforçada e sempre'
linha15 = 'busco sair da minha zona de conforto.'
linha16 = ''
conteudo_linhas = [linha1, linha2, linha3, linha4, linha5, linha6, linha7, linha8, linha9, linha10, linha11, linha12, linha13, linha14, linha15]


TrabalhoTitulo = 'EXPERIÊNCIA PROFISSIONAL'
TrabalhoZeroTitulo = 'Accenture / Software Engineering Analyst'
TrabalhoZeroPeriodo = '10/2020-Atual'
TrabalhoZeroDescr = '- Desenvolvimento de modelo de OCR/IA para extração\n  de informação de documentos não estruturados\n- Integrante do time de Google Cloud'
TrabalhoUmTitulo = 'Empresa Gaúcha de Rodovias / Engenheira Civil'
TrabalhoUmPeriodo = '07/2018-09/2020'
TrabalhoUmDescr = '- Coordenação de serviços de sinalização em 900km\n  de rodovias\n- Planejamento e acompanhamento dos serviços\n- Automatização de tarefas repetitivas da função'
TrabalhoDoisTitulo = 'CORSAN / Engenheira Civil'
TrabalhoDoisPeriodo = '02/2015-02/2016'
TrabalhoDoisDescr = '- Elaboração de orçamentos utilizando Excel/VBA'

EduTitulo = 'EDUCAÇÃO'
EduUmTitulo = 'DIGITAL HOUSE, Dev. Web Full Stack | Data Science'
EduUmPeriodo = '2020-2021 | 2021-2021'
EduDoisTitulo = 'UFRGS, Eng. Civil (Completo) | Eng. Elétrica (Incomp.)'
EduDoisPeriodo = '2009-2013 | 2007-2009'
EduTresTitulo = 'UFRGS, MSc. Engenharia Civil'
EduTresPeriodo = '2016-2018'
EduTresDescr = '- Área de concentração: Estruturas'

#Descrição Linguagens
titulo_linguagens = 'Linguagens/Libraries'
ling1 = '- Python' #.7
ling2 = '- Pandas/Numpy' #.7
ling3 = '- Scikit-learn' #.7
ling4 = '- SQL' #.3
ling5 = '- JavaScript' #.6
ling6 = '- Express.JS' #.4
ling7 = '- HTML/CSS' #.5
ling_conteudo_linhas = [ling1, ling2, ling3, ling4, ling5, ling6, ling7]
ling_percentuais = [.7, .7, .7, .3, .6, .4, .5]

#Descrição Ferramentas
titulo_ferramentas = 'Ferramentas'
ferr1 = '- VS Code' #.9
ferr2 = '- GCP' #.5
ferr3 = '- Azure' #.5
ferr4 = '- IBM Watson' #.6
ferr5 = '- GCP AutoML' #.4
ferr6 = '- Node.JS' #.5
ferr7 = '- Git/GitHub' #.4 
ferr8 = '- Excel' #.9
ferr_conteudo_linhas = [ferr1, ferr2, ferr3, ferr4, ferr5, ferr6, ferr7, ferr8]
ferr_percentuais = [.9, .5, .5, .6, .4, .5, .4, .9]

#Descrição Habilidades/Conhecimentos
titulo_habilidades = 'Conhecimentos'
hab1 = '- Matemát./Estat.' #.9
hab2 = '- Lógica program.' #.9
hab3 = '- Cloud' #.6
hab4 = '- Sistemas web' #.5
hab5 = '- OCR/IA' #.75
hab_conteudo_linhas = [hab1, hab2, hab3, hab4, hab5]
hab_percentuais = [.9, .9, .6, .5, .8]

#Descrição Soft Skills
titulo_soft = 'Soft Skills'
soft1 = '- Comunicação' #.7
soft2 = '- Colaboração' #.8
soft3 = '- Resiliência' #.9
soft4 = '- Flexibilidade' #.6
soft5 = '- Criatividade' #.7
soft_conteudo_linhas = [soft1, soft2, soft3, soft4, soft5]
soft_percentuais = [.7, .8, .9, .6, .7]

#Descrição Línguas
titulo_linguas = 'Línguas'
linguas1 = '- Inglês'
linguas2 = '- Espanhol'
linguas_conteudo_linhas = [linguas1, linguas2]
linguas_percentuais = [0.7, 0.3]


# Setting style for bar graphs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Ajuste da fonte
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'DejaVu Sans'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Ajuste das cores
cinza = '#808080'
azul = '#2e2eb8'
branco = '#ffffff'

# Ajuste das Linhas Decorativas
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color=cinza, alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=1, xmin=0, xmax=1, color=azul, linewidth=141, alpha=0.5)

# Definindo a cor de fundo da imagem
ax.set_facecolor('white')

# Removendo os eixos
plt.axis('off')


### ANOTAÇÕES DOS TEXTOS

## Títulos
plt.annotate(Nota, (.02,.99), weight='regular', fontsize=6.5, alpha=.75)
plt.annotate(Nome, (.02,.943), weight='bold', fontsize=20)
plt.annotate(Titulo, (.02,.91), weight='regular', fontsize=13)
plt.annotate(Contato, (.7,.906), weight='regular', fontsize=8, color='#ffffff')

## Texto Quem Sou Eu

#Construção vetor localização
num_linhas = len(conteudo_linhas) + 1
loc_linha_inicial = .83
passo = -.015
loc_linha_final = loc_linha_inicial + passo * (num_linhas-1)
loc_linhas = pd.Series(  np.arange(loc_linha_inicial,loc_linha_final,passo)  , index=range(0,num_linhas-1))

#Anotação do texto
plt.annotate(TituloQuemSouEu, (.02,.85), weight='bold', fontsize=10, color=azul)
for i in loc_linhas.index:
    plt.annotate(conteudo_linhas[i], (.02,loc_linhas[i]), weight='regular', fontsize=7.9)

## Texto Experiência Profissional
plt.annotate(TrabalhoTitulo, (.02,.58), weight='bold', fontsize=10, color=azul)
plt.annotate(TrabalhoZeroTitulo, (.02,.555), weight='bold', fontsize=10)
plt.annotate(TrabalhoZeroPeriodo, (.02,.535), weight='regular', fontsize=9, alpha=.6)
plt.annotate(TrabalhoZeroDescr, (.04,.48), weight='regular', fontsize=9)
plt.annotate(TrabalhoUmTitulo, (.02,.45), weight='bold', fontsize=10)
plt.annotate(TrabalhoUmPeriodo, (.02,.43), weight='regular', fontsize=9, alpha=.6)
plt.annotate(TrabalhoUmDescr, (.04,.355), weight='regular', fontsize=9)
plt.annotate(TrabalhoDoisTitulo, (.02,.325), weight='bold', fontsize=10)
plt.annotate(TrabalhoDoisPeriodo, (.02,.305), weight='regular', fontsize=9, alpha=.6)
plt.annotate(TrabalhoDoisDescr, (.04,.285), weight='regular', fontsize=9)

#Anotação da Educação
plt.annotate(EduTitulo, (.02,.240), weight='bold', fontsize=10, color=azul)
plt.annotate(EduUmTitulo, (.02,.21), weight='bold', fontsize=10)
plt.annotate(EduUmPeriodo, (.02,.19), weight='regular', fontsize=9, alpha=.6) #+15
plt.annotate(EduDoisTitulo, (.02,.15), weight='bold', fontsize=10) #+45
plt.annotate(EduDoisPeriodo, (.02,.13), weight='regular', fontsize=9, alpha=.6) #+15
plt.annotate(EduTresTitulo, (.02,.08), weight='bold', fontsize=10) #+45
plt.annotate(EduTresPeriodo, (.02,.06), weight='regular', fontsize=9, alpha=.6) #+15
plt.annotate(EduTresDescr, (.02,.04), weight='regular', fontsize=9, alpha=.6) #+15


################      FUNÇÕES PARA MONTAR AS BARRAS DE DESEMPENHO DAS HABILIDADES

def locate_vector(titulo, quantidade, loc_linha_inicial, passo):
    loc_linha_final = round(loc_linha_inicial + passo * quantidade,2)
    print('Localização linha final ' + titulo + str(loc_linha_final))
    vector = np.arange(loc_linha_inicial,loc_linha_final,passo)
    locate_vector = pd.Series(vector, index=range(0,len(vector)))
    return locate_vector
    
def lines(locate_vector, tamanho, percentuais, cor):
    for i in locate_vector.index:
        plt.axhline(y=locate_vector[i]+.0035, xmin=(1-tamanho*percentuais[i]), xmax=1, color=cor, linewidth=7, alpha=0.7)
        
def white_lines(locate_vector, tamanho, cor):
    for i in locate_vector.index:
        plt.axhline(y=locate_vector[i]+.0035, xmin=(1-tamanho), xmax=1, color=cor, linewidth=7, alpha=0.4)
        
def annotate(titulo, loc_titulo, conteudo, locate_vector):
    plt.annotate(titulo, (.7,loc_titulo), weight='bold', fontsize=10, color=azul)
    for i in locate_vector.index:
        plt.annotate(conteudo[i], (.7,locate_vector[i]), weight='regular', fontsize=9, color=branco)

#####     LINGUAGENS/LIBRARIES     #####

ling_vector = locate_vector('Linguagens/Libraries', len(ling_conteudo_linhas), .82, -.02)
white_lines(ling_vector, .11, '#ffffff')
lines(ling_vector, .11, ling_percentuais, azul)
annotate(titulo_linguagens, .85, ling_conteudo_linhas, ling_vector)


#####     FERRAMENTAS     #####    

ferr_vector = locate_vector('Ferramentas', len(ferr_conteudo_linhas), .62, -.02)
white_lines(ferr_vector, .11, '#ffffff')
lines(ferr_vector, .11, ferr_percentuais, azul)
annotate(titulo_ferramentas, .65, ferr_conteudo_linhas, ferr_vector)
    
#####     HABILIDADES/CONHECIMENTOS     #####

hab_vector = locate_vector('Habilidades/Conhecimentos', len(hab_conteudo_linhas), .38, -.02)
white_lines(hab_vector, .11, '#ffffff')
lines(hab_vector, .11, hab_percentuais, azul)
annotate(titulo_habilidades, .41, hab_conteudo_linhas, hab_vector)
    
#####     SOFT SKILLS     #####

soft_vector = locate_vector('Soft Skills', len(soft_conteudo_linhas), .22, -.02)
white_lines(soft_vector, .11, '#ffffff')
lines(soft_vector, .11, soft_percentuais, azul)
annotate(titulo_soft, .25, soft_conteudo_linhas, soft_vector)

#####     LÍNGUAS     #####

# Desenha os círculos das Línguas
ax1 = fig.add_axes([0.47,0.58,0.2,0.2])
ax1.set_autoscale_on(True)
localizacao_ingles = (0.5,0.75)
localizacao_espanhol = (0.5,0.25)
raio = 0.18
circulo_background_ingles = plt.Circle(localizacao_ingles, raio, color=cinza, alpha=0.4)
circulo_background_espanhol = plt.Circle(localizacao_espanhol, raio, color=cinza, alpha=0.4)
circulo_ingles = plt.Circle(localizacao_ingles, raio*0.9, color=azul, alpha=0.7)
circulo_espanhol = plt.Circle(localizacao_espanhol, raio*0.25, color=azul, alpha=0.7)
ax1.set_aspect(1)
ax1.add_artist(circulo_background_ingles)
ax1.add_artist(circulo_background_espanhol)
ax1.add_artist(circulo_ingles)
ax1.add_artist(circulo_espanhol)

titulo_ingles = 'Inglês'
plt.annotate(titulo_ingles, (.345,0.98), weight='bold', fontsize=10, color=azul)
titulo_espanhol = 'Espanhol'
plt.annotate(titulo_espanhol, (.29,0.49), weight='bold', fontsize=10, color=azul)

plt.axis('off')

# Plotando QR code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('QR-Code.png')
imagebox = OffsetImage(arr_code, zoom=0.03)
ab = AnnotationBbox(imagebox, (0.835, 0.07))
ax.add_artist(ab)

# Salvando imagem em png
plt.savefig('CV-Carla.png', dpi=300, bbox_inches='tight')

# Salvando documento em pdf
from PIL import Image
image1 = Image.open('CV-Carla.png')
im1 = image1.convert('RGB')
im1.save('CV-Carla.pdf')
# Out:
# Localização linha final Linguagens/Libraries0.68
# Localização linha final Ferramentas0.46
# Localização linha final Habilidades/Conhecimentos0.28
# Localização linha final Soft Skills0.12
